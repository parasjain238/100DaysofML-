# %% [markdown]
# JSON AND SQL
# JSON use mainly in API or work with python and java language
# sql type of file formatee like csv

# %%
import pandas as pd

# %%
pd.read_json('/content/train.json')
#pd.read_json(" yha par koi bhi website ke link se data le skte hai")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # working with sql

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 71.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=5710c8926290be9edbb0fd71f86150421ebc98fc4f19f53b83de754518665846
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %% [markdown]
# I am unable to do this bacause unable to download  {xampp} due to apple user
# xampp - dowload then open start apache and mysql
# go to chrome
# localhost/phpadmin/
# then make folder world and do

# %%
mysql.connector.connect(host = 'localhost', user='root',password='',database='world')

# %%
# !apt-get remove --purge mysql-server mysql-client mysql-common -y
# !apt-get autoremove -y
# !apt-get autoclean
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'mysql-client' is not installed, so not removed
# The following packages were automatically installed and are no longer required:
#   gdal-data gdal-plugins libaio1 libaom-dev libarmadillo-dev libarmadillo10
#   libarpack2 libarpack2-dev libblosc-dev libblosc1 libboost-dev
#   libboost1.74-dev libcfitsio-dev libcfitsio9 libcgi-fast-perl libcgi-pm-perl
#   libclone-perl libdav1d-dev libde265-0 libde265-dev libencode-locale-perl
#   libfcgi-bin libfcgi-perl libfcgi0ldbl libfreexl-dev libfreexl1 libfyba-dev
#   libfyba0 libgeos-c1v5 libgeos-dev libgeos3.12.1 libgeotiff-dev libgeotiff5
#   libgif-dev libhdf4-0-alt libhdf4-alt-dev libheif-dev libheif1
#   libhtml-parser-perl libhtml-tagset-perl libhtml-template-perl
#   libhttp-date-perl libhttp-message-perl libio-html-perl libjbig-dev
#   libjson-c-dev libkml-dev libkmlbase1 libkmlconvenience1 libkmldom1
# ...
