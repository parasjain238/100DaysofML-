# %% [markdown]
# data gathering - csv file formate , Json/sql ,
# Fetch API , WEB scraping( these cover in next four viedos)

# %% [markdown]
# Today lean about csv files

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/cs2_all_tiers_games.csv")
df
# Out:
#        Unnamed: 0  match_id   game_id  \
# 0               0   7299109  153292.0
# 1               1   7299109  153294.0
# 2               2   7299109 -153292.0
# 3               3   7299050  153284.0
# 4               4   7299050  153289.0
# ...           ...       ...       ...
# 19026        1009  10064202       NaN
# 19027        1010  10064200       NaN
# 19028        1011  10064199       NaN
# 19029        1012  10064198       NaN
# 19030        1013  10064201       NaN
#
#                                        tournament  team1_id    team1  \
# 0      PGL Astana 2026. Closed European Qualifier    289672    magic
# 1      PGL Astana 2026. Closed European Qualifier    289672    magic
# 2      PGL Astana 2026. Closed European Qualifier    289672    magic
# 3      PGL Astana 2026. Closed European Qualifier    289670      K27
# 4      PGL Astana 2026. Closed European Qualifier    289670      K27
# ...                                           ...       ...      ...
# ...

# %% [markdown]
# 3. opening a csv file from an url

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/plotly/datasets/refs/heads/master/data.csv"
headers = {"User-Agent": "Monilla/5.0 (macintosh; Intel Mac OS x 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149997                 0                              0.246044   58
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          2     0.802982         9120.0
# ...

# %% [markdown]
# 4. SET PARAMETER
# like wothout use an sep = '\t' occuring an problem like merged show
# or name will provide using list

# %%
pd.read_csv("/content/movie_titles_metadata.tsv", sep='\t', names = ['sno','name','relase_year','rating','votes','genres'])
# Out:
#       sno                        name relase_year  rating     votes  \
# 0      m0  10 things i hate about you        1999     6.9   62847.0
# 1      m1  1492: conquest of paradise        1992     6.2   10421.0
# 2      m2                  15 minutes        2001     6.1   25854.0
# 3      m3       2001: a space odyssey        1968     8.4  163227.0
# 4      m4                     48 hrs.        1982     6.9   22289.0
# ..    ...                         ...         ...     ...       ...
# 612  m612                    watchmen        2009     7.8  135229.0
# 613  m613                         xxx        2002     5.6   53505.0
# 614  m614                       x-men        2000     7.4  122149.0
# 615  m615          young frankenstein        1974     8.0   57618.0
# 616  m616                   zulu dawn        1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# 6. HEADER PARARMETER - USE WHEN LIKE YOUE COLOMN NAME SHOW AS YOUR ROW NAME ( here is this type of dtat set is not avaivble so error may got)

# %%
pd.read_csv("/content/cs2_all_tiers_games.csv")
#header=1 sahi karrne kke liye
# Out:
#        Unnamed: 0  match_id   game_id  \
# 0               0   7299109  153292.0
# 1               1   7299109  153294.0
# 2               2   7299109 -153292.0
# 3               3   7299050  153284.0
# 4               4   7299050  153289.0
# ...           ...       ...       ...
# 19026        1009  10064202       NaN
# 19027        1010  10064200       NaN
# 19028        1011  10064199       NaN
# 19029        1012  10064198       NaN
# 19030        1013  10064201       NaN
#
#                                        tournament  team1_id    team1  \
# 0      PGL Astana 2026. Closed European Qualifier    289672    magic
# 1      PGL Astana 2026. Closed European Qualifier    289672    magic
# 2      PGL Astana 2026. Closed European Qualifier    289672    magic
# 3      PGL Astana 2026. Closed European Qualifier    289670      K27
# 4      PGL Astana 2026. Closed European Qualifier    289670      K27
# ...                                           ...       ...      ...
# ...

# %% [markdown]
# 7. USE_COL paramter -  means data insert karte hai to kuch colomn he chiaye pate hai ya kuch unnnesary hote hai

# %%
pd.read_csv("/content/cs2_all_tiers_games.csv",usecols=['match_id','game_id' , 'tournament'])
# Out:
#        match_id   game_id                                  tournament
# 0       7299109  153292.0  PGL Astana 2026. Closed European Qualifier
# 1       7299109  153294.0  PGL Astana 2026. Closed European Qualifier
# 2       7299109 -153292.0  PGL Astana 2026. Closed European Qualifier
# 3       7299050  153284.0  PGL Astana 2026. Closed European Qualifier
# 4       7299050  153289.0  PGL Astana 2026. Closed European Qualifier
# ...         ...       ...                                         ...
# 19026  10064202       NaN                           Buster CS2 League
# 19027  10064200       NaN                           Buster CS2 League
# 19028  10064199       NaN                           Buster CS2 League
# 19029  10064198       NaN                           Buster CS2 League
# 19030  10064201       NaN                           Buster CS2 League
#
# [19031 rows x 3 columns]

# %% [markdown]
# 8. squeeze parameter - means only one colomn are need
# squeeze = ture ( aab yh data frame na bnkar ke pandas series ban jata hai)

# %%
pd.read_csv("/content/cs2_all_tiers_games.csv", usecols=['match_id'] )
# Out:
#        match_id
# 0       7299109
# 1       7299109
# 2       7299109
# 3       7299050
# 4       7299050
# ...         ...
# 19026  10064202
# 19027  10064200
# 19028  10064199
# 19029  10064198
# 19030  10064201
#
# [19031 rows x 1 columns]

# %% [markdown]
# 9. SKIPROES/NROWS PARARMETER
# nrow = 100 ( means apko jitni need hai utna usae kar skate hai_)

# %%
# pd.read_csv("/content/cs2_all_tiers_games.csv" , skiprows=[0,1])
pd.read_csv("/content/cs2_all_tiers_games.csv" , nrows=100)
# Out:
#     Unnamed: 0  match_id  game_id                                  tournament  \
# 0            0   7299109   153292  PGL Astana 2026. Closed European Qualifier
# 1            1   7299109   153294  PGL Astana 2026. Closed European Qualifier
# 2            2   7299109  -153292  PGL Astana 2026. Closed European Qualifier
# 3            3   7299050   153284  PGL Astana 2026. Closed European Qualifier
# 4            4   7299050   153289  PGL Astana 2026. Closed European Qualifier
# ..         ...       ...      ...                                         ...
# 95          95   7048401   125786                      BLAST Open Spring 2026
# 96          96   7048401  -125784                      BLAST Open Spring 2026
# 97          97   7042616   125782                      BLAST Open Spring 2026
# 98          98   7042616   125783                      BLAST Open Spring 2026
# 99          99   7042616   125781                      BLAST Open Spring 2026
#
# ...

# %% [markdown]
# 12. DTYPE PARARMETER

# %%
pd.read_csv('/content/cs2_all_tiers_games.csv',dtype={'score2_match': int})
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py:234: RuntimeWarning: invalid value encountered in cast
#   chunks = self._reader.read_low_memory(nrows)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33704/1537890124.py in <cell line: 0>()
# ----> 1 pd.read_csv('/content/cs2_all_tiers_games.csv',dtype={'score2_match': int})
#
# ...

# %% [markdown]
# 13. HANDLING DATES
