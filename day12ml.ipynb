# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# 1. import dataset

# %% [markdown]
# over here we will input the data set

# %% [markdown]
# 1.heading

# %% [markdown]
# 2.subheading

# %%
# pandas
import pandas as pd

# %%
pd.read_csv('cs2_all_tiers_games.csv')
# Out:
#        Unnamed: 0  match_id   game_id  \
# 0               0   7299109  153292.0
# 1               1   7299109  153294.0
# 2               2   7299109 -153292.0
# 3               3   7299050  153284.0
# 4               4   7299050  153289.0
# ...           ...       ...       ...
# 19026        1009  10064202       NaN
# 19027        1010  10064200       NaN
# 19028        1011  10064199       NaN
# 19029        1012  10064198       NaN
# 19030        1013  10064201       NaN
#
#                                        tournament  team1_id    team1  \
# 0      PGL Astana 2026. Closed European Qualifier    289672    magic
# 1      PGL Astana 2026. Closed European Qualifier    289672    magic
# 2      PGL Astana 2026. Closed European Qualifier    289672    magic
# 3      PGL Astana 2026. Closed European Qualifier    289670      K27
# 4      PGL Astana 2026. Closed European Qualifier    289670      K27
# ...                                           ...       ...      ...
# ...
